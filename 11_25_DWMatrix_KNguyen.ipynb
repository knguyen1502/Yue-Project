# %% [markdown]
# <a href="https://colab.research.google.com/github/knguyen1502/Yue-Project/blob/main/11_25_DWMatrix_KNguyen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Set up

# %%
import math
import scipy.integrate
import numpy as np
import pandas as pd
import sympy
# !git config  --global user.email "knguyen20@luc.edu"
# !git config  --global user.name "knguyen1502"
pat = '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'
# !git clone https://{pat}@github.com/knguyen1502/Yue-Project.git
# %cd Yue-Project
# Out:
# /bin/bash: knguyen1502: No such file or directory
# [Errno 2] No such file or directory: 'Yue-Project'
# /content/Yue-Project

# %% [markdown]
# #Constant (GeV)

# %%
Mpl = 1.3 * 10**(19)
GF = 1.16 * 10**(-5)
MW = 80.385
MZ = 91.1876
μ = 10**(-3)
ρo = 1.05* 10**(-5)
so = 2891.2
ms = 0
# !ls
# Out:
#  11_1_DWMatrix_FreshStart.nb	   NonEqList_mph1_lam0pt1.dat
# '9_22 DWFromDensityMatrix.nb'	   seeds_mph0pt1_lam0pt003.dat
#  GstarH.txt			   seeds_mph1_lam0pt1.dat
#  GstarS.txt			   SelfIntSNu_WT_221019.nb
#  NonEqList_mph0pt1_lam0pt003.dat

# %% [markdown]
# #Standard definitions

# %%
tgH = np.genfromtxt('GstarH.txt')
tgS = np.genfromtxt('GstarS.txt')
tempH=tgH[:,0][::-1] 
tempS=tgS[:,0][::-1] 
dofH=tgH[:,1][::-1]
dofS=tgS[:,1][::-1]
def Δ(x,z):
  return (ms**2*z)/2*x*μ
def VT(x,z):
  return (4.342404391* GF * x * μ**5 / z**5) * (1/MZ**2 + 2/MW**2)
def Γa(x,z):
  return GF**2 * x * μ**5 / z**5
def Hubble(z):
    return 1.66*np.sqrt(np.interp(μ/z,tempH,dofH))*(μ/z)**2/Mpl

# %%
# Out:
# 2.1648617889932874e-23

# %% [markdown]
# #Upload to github repo:
# https://github.com/knguyen1502/Yue-Project

# %%
# Out:
# Reinitialized existing Git repository in /content/Yue-Project/.git/
# On branch main
# nothing to commit, working tree clean
# remote: Permission to knguyen1502/Yue-Project.git denied to knguyen1502.
# fatal: unable to access 'https://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@github.com/knguyen1502/Yue-Project.git/': The requested URL returned error: 403
